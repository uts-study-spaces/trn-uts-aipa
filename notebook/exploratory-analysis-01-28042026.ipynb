# %%
# import libraries
import os
import pandas as pd

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# You need to define your own .evn file with the 'DATA_PATH' evironment variable. This variable points 
# to the data's location in your machine. You can modify the .example.env file to  Retrieving from the .env file prevents explicit path
DATA_PATH = os.getenv('DATA_PATH')
database = pd.read_csv(DATA_PATH, index_col='ticket_id')

# %%
database
# Out:
#                customer_name                   customer_email  \
# ticket_id
# 1             Patricia Smith    patricia.smith760@outlook.com
# 2          Patricia Williams   patricia.williams390@gmail.com
# 3           William Anderson  william.anderson651@outlook.com
# 4               David Miller       david.miller672@icloud.com
# 5            Robert Gonzalez   robert.gonzalez391@hotmail.com
# ...                      ...                              ...
# 199996      Barbara Martinez  barbara.martinez691@hotmail.com
# 199997       James Hernandez   james.hernandez188@hotmail.com
# 199998        Michael Thomas     michael.thomas66@company.com
# 199999        Barbara Taylor    barbara.taylor486@outlook.com
# 200000       Patricia Wilson     patricia.wilson865@yahoo.com
#
#                     product                   category  \
# ticket_id
# 1                Web Portal         Account Suspension
# 2                Mobile App          Performance Issue
# ...
